# %%
my_name = "Peter"
print("Hello, " + my_name + " and I am learning Python.")
first_num = 5
second_num = 10
print("The sum of", first_num, "and", second_num, "is", first_num + second_num)
# Out:
# Hello, Peter and I am learning Python.
# The sum of 5 and 10 is 15
